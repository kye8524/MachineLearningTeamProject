# %%
# !pip install import_ipynb

# %%
# 0. 모듈 불러오기

import import_ipynb

from load_data import train_data, song_meta, genre_gn_all

# %%
# 1. 데이터 구조 훑어보기

# 1-1. train_data
train_data.head()
# Out:
#                                                 tags      id  \
# 0                                                [락]   61281
# 1                                           [추억, 회상]   10532
# 2                                          [까페, 잔잔한]   76951
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  147456
# 4                                               [댄스]   27616
#
#             plylst_title                                              songs  \
# 0                여행같은 음악  [525514, 129701, 383374, 562083, 297861, 13954...
# 1                요즘 너 말야  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  편하게, 잔잔하게 들을 수 있는 곡.-  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  크리스마스 분위기에 흠뻑 취하고 싶을때  [394031, 195524, 540149, 287984, 440773, 10033...
# 4               추억의 노래 ㅋ  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#    like_cnt                updt_date
# 0        71  2013-12-19 18:36:19.000
# 1         1  2014-12-02 16:19:42.000
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115071 entries, 0 to 115070
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   tags          115071 non-null  object
#  1   id            115071 non-null  int64
#  2   plylst_title  115071 non-null  object
#  3   songs         115071 non-null  object
#  4   like_cnt      115071 non-null  int64
#  5   updt_date     115071 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 5.3+ MB

# %%
# 좋아요 개수

train_data['like_cnt'].describe()
# Out:
# count    115071.000000
# mean         95.197687
# std         560.653757
# min           0.000000
# 25%           2.000000
# 50%           7.000000
# 75%          24.000000
# max       53211.000000
# Name: like_cnt, dtype: float64

# %%
# 1-2. song_meta

song_meta.head()
# Out:
#   song_gn_dtl_gnr_basket  issue_date  \
# 0               [GN0901]    20140512
# 1       [GN1601, GN1606]    20080421
# 2               [GN0901]    20180518
# 3       [GN1102, GN1101]    20151016
# 4       [GN1802, GN1801]    20110824
#
#                                           album_name  album_id  \
# 0                       불후의 명곡 - 7080 추억의 얄개시대 팝송베스트   2255639
# 1                      Bach : Partitas Nos. 2, 3 & 4    376431
# 2                                                Hit   4698747
# 3  Feeling Right (Everything Is Nice) (Feat. Popc...   2644882
# 4                                            그남자 그여자   2008470
#
#   artist_id_basket                                          song_name  \
# 0           [2727]                                           Feelings
# 1          [29966]  Bach : Partita No. 4 In D Major, BWV 828 - II....
# 2           [3361]                    Solsbury Hill (Remastered 2002)
# 3         [838543]  Feeling Right (Everything Is Nice) (Feat. Popc...
# ...

# %%
song_meta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 707989 entries, 0 to 707988
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   song_gn_dtl_gnr_basket  707989 non-null  object
#  1   issue_date              707989 non-null  int64
#  2   album_name              707985 non-null  object
#  3   album_id                707989 non-null  int64
#  4   artist_id_basket        707989 non-null  object
#  5   song_name               707989 non-null  object
#  6   song_gn_gnr_basket      707989 non-null  object
#  7   artist_name_basket      707989 non-null  object
#  8   id                      707989 non-null  int64
# dtypes: int64(3), object(6)
# memory usage: 48.6+ MB

# %%
# 해당 대장르를 가진 노래 Count

def count_gn_gnr(genre):
    count=0;
    for genre_list in song_meta['song_gn_gnr_basket']:
        for item in genre_list:
            if (item == genre):
                count = count + 1
    return count

print(find_gnr_name('GN3000'), count_gn_gnr('GN3000'))
# Out:
# 크리스마스 0

# %%
# 대장르별 노래 Count

for i in range(1,31):
    print(find_gnr_name(f'GN{i:02d}00'), count_gn_gnr(f'GN{i:02d}00'))
# Out:
# 발라드 56820
# 댄스 19017
# 랩/힙합 27784
# R&B/Soul 14476
# 인디음악 42468
# 록/메탈 29690
# 성인가요 12673
# 포크/블루스 15203
# POP 77101
# 록/메탈 63926
# 일렉트로니카 60144
# 랩/힙합 35376
# R&B/Soul 32784
# 포크/블루스/컨트리 13365
# OST 44272
# 클래식 57066
# 재즈 48199
# 뉴에이지 42515
# J-POP 21413
# 월드뮤직 13218
# CCM 20002
# 어린이/태교 16706
# 종교음악 1137
# 국악 2228
# 아이돌 12066
# 일렉트로니카 6400
# EDM 11440
# 뮤직테라피 1783
# 뮤지컬 1753
# 크리스마스 0

# %%
# 키워드로 플레이리스트 검색

chistmas_playlist = []
chistmas_playlist_lndex = []
for index in train_data.index:
    title = train_data['plylst_title'][index]
    if('크리스마스' in title or '캐럴' in title or '캐롤' in title):
        chistmas_playlist.append(title)
        chistmas_playlist_lndex.append(index)

print(len(chistmas_playlist))
print(chistmas_playlist)
# Out:
# 1634
# ...

# %%
# 크리스마스 플레이리스트에 있는 곡 검색

chistmas_song = []
for index in chistmas_playlist_lndex:
    songs = train_data['songs'][index]
    for song in songs:
# Out:
# 크리스마스 분위기에 흠뻑 취하고 싶을때
# 크리스마스를 책임질 캐롤 모음
# 느낌있는 크리스마스 쏭
# 크리스마스9
# 미리 메리 크리스마스
# 우리카페에서 들려주는 크리스마스 캐럴
# 신나는 크리스마스에 어울리는 캐롤과 노래! 준비했어 널 위해~
# 크리스마스 분위기 물씬 나는 곡들 총집합!
# 선곡이좋은 <주말카페>에서 들리는 달달한 봄캐롤송.
# 봄에 듣는 크리스마스 송
# ★ 올 댓 크리스마스 캐롤! ★
# 크리스마스를 앞두고, 아이돌의 겨울 노래
# 크리스마스를 맞이하며
# 신나는크리스마스
# 베리베리 해피 메리 크리스마스~!!!
# 크리스마스 노래에 퐁당 빠져보아요
# 따뜻한 카페에서 듣고 싶은 재즈 캐롤 연주곡
# 크리스마스156
# 미리 크리스마스 즐겨요
# 밝고 설렘 가득 크리스마스 시즌을 위한 캐롤들!
# 메리 크리스마스 !
# ✔️올 크리스마스는 요고당! 매력적인 음색의 R&B/팝 캐롤⛄️
# 미리 메리크리스마스
# 미리 메리 크리스마스
# 카페에서 듣고 싶은 크리스마스 캐롤 ♬
# 크리스마스 캐롤~ 잔잔하게 듣기좋은곡 모음 Merry Christmas
# 크리스마스 마무리 캐롤
# 기품있고 도도한 클래식 캐롤
# 좀 있으면 벌써 크리스마스 ... 미리 듣는 성탄절 노래
# 스위리 메리 크리스마스
# ★이번주가 크리스마스야★
# 크리스마스426
# 크리스마스332
# 크리스마스까지 계속 듣자
# 크리스마스를 위한 추천곡 20선
# 크리스마스204
# 크리스마스 데이트를 위한 달달한 Soul/Funk
# 미리 듣는 크리스마스
# 집에서 둘이 듣는 크리스마스
# 마음이 편안해지는 크리스마스
# ···♥크리스마스 노래모음♥···
# 크리스마스335
# 미리크리스마스Music♬
# 크리스마스393
# 잔잔한 분위기 크리스마스
# 크리스마스 카페 음악
# 너무 올드하지도 너무 낯설지도 않은, 편안하게 즐기는 크리스마스 캐롤
# 어느새 겨울, 크리스마스 ~
# 듣고있으면 봄향기 가득! 계속 듣고싶어지는 봄캐롤.
# 겨울 감성 채워줄 뉴에이지 캐롤
# ...

# %%
# 1-3. genre_gn_all

genre_gn_all
# Out:
#     gnr_code gnr_name
# 0     GN0100      발라드
# 1     GN0101   세부장르전체
# 2     GN0102      '80
# 3     GN0103      '90
# 4     GN0104      '00
# ..       ...      ...
# 249   GN2900      뮤지컬
# 250   GN2901   세부장르전체
# 251   GN2902    국내뮤지컬
# 252   GN2903    국외뮤지컬
# 253   GN3000    크리스마스
#
# [254 rows x 2 columns]

# %%
# 장르 Code로 장르 Name을 찾는 함수

def find_gnr_name(code):
    for index in genre_gn_all.index:
        if (genre_gn_all['gnr_code'][index] == code):
            return genre_gn_all['gnr_name'][index]

find_gnr_name('GN3000')
# Out:
# '크리스마스'

# %%
# 장르코드 : 장르이름

for index in genre_gn_all['gnr_code'].index:
    print(genre_gn_all['gnr_code'][index] + " : " + genre_gn_all['gnr_name'][index])
# Out:
# GN0100 : 발라드
# GN0101 : 세부장르전체
# GN0102 : '80
# GN0103 : '90
# GN0104 : '00
# GN0105 : '10-
# GN0200 : 댄스
# GN0201 : 세부장르전체
# GN0202 : '80
# GN0203 : '90
# GN0204 : '00
# GN0205 : '10-
# GN0300 : 랩/힙합
# GN0301 : 세부장르전체
# GN0302 : 랩 스타일
# GN0303 : 보컬 스타일
# GN0304 : 언더그라운드 힙합
# GN0305 : 시대별
# GN0400 : R&B/Soul
# GN0401 : 세부장르전체
# GN0402 : 어반
# GN0403 : R&B
# GN0500 : 인디음악
# GN0501 : 세부장르전체
# GN0502 : 포크
# GN0503 : 록
# GN0504 : 일렉
# GN0505 : 힙합
# GN0506 : 발라드
# GN0507 : '90
# GN0508 : '00
# GN0509 : '10-
# GN0600 : 록/메탈
# GN0601 : 세부장르전체
# GN0602 : '70
# GN0603 : '80
# GN0604 : '90
# GN0605 : '00
# GN0606 : '10-
# GN0700 : 성인가요
# GN0701 : 세부장르전체
# GN0702 : 신세대트로트
# GN0703 : 전설의트로트
# GN0704 : 뽕짝트로트
# GN0705 : 트로트메들리
# GN0706 : 트로트'60-'70
# GN0707 : 트로트'80-'90
# GN0708 : 트로트'00-
# GN0709 : 성인가요'80-'90
# GN0710 : 성인가요'00-
# GN0800 : 포크/블루스
# GN0801 : 세부장르전체
# GN0802 : '60-'70
# GN0803 : '80-'90
# GN0804 : '00
# GN0805 : '10-
# GN0900 : POP
# GN0901 : 세부장르전체
# GN0902 : 얼터너티브팝
# ...
